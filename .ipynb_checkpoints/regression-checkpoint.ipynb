# %%
import numpy as np
from sklearn.datasets import load_diabetes
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
class simpleLR:
    def __init__(self,m,b):
        self.m=m
        self.b=b
    def fit(self,x_train,y_train):
        num=0
        den=0
        xmean=x_tarin.mean()
        ymean=y_tarin.mean()
        for i in range(x_train.shape[0]):
            num+=(y_train[i]-ymean)(x_train[i]-xmean)
            den+=((x_train[i]-xmean)*(x_train[i]-xmean))
        self.m=num/float(den)
        self.b=ymean-self.m*xmean
    def predict(self,x_test):
        return m*x_test+b

# %%
class Linear_Regression:
    def __init__(self):
        self.coef_=None
        self.intercept_=None
    def fit(self,x_train,y_train):
        x_train=np.insert(x_train,0,1,axis=1)
        beta=np.linalg.pinv(x_train) @ y_train
        self.intercept_=beta[0]
        self.coef_=beta[1:]
    def predict(self,x_test):
        return np.dot(x_test,self.coef_)+self.intercept_

# %%
x,y=load_diabetes(return_X_y=True)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
LR=LinearRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=LR.predict(x_test)

# %%
# lets try our linear regression

# %%
reg=Linear_Regression()

# %%
reg.fit(x_train,y_train)

# %%
Y_predt=reg.predict(x_test)

# %%
# lets campare both

# %%
#r2 scores

# %%
#sklear
r2_score(y_test,y_pred)
# Out:
# 0.439933866156897

# %%
#mine
r2_score(y_test,Y_predt)
# Out:
# 0.43993386615689634

# %%
#intercept

# %%
#sklear 
LR.intercept_
# Out:
# np.float64(151.88331005254167)

# %%
#mine
reg.intercept_
# Out:
# np.float64(151.8833100525407)

# %%
#coeffient

# %%
#sklearn
LR.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
#mine
reg.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])
